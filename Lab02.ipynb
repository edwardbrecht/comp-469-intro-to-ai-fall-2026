# %% [markdown]
# # Lab 02
# ## 1. The 3-Square Vacuum World
# ### (a)
# a) There are 6 distinct percepts in this case. <br>
# b) There are $ 6^t $ distinct percept sequences of length t. <br>
# c) A closed-form expression for the number of rows for a lookup table of every percept sequence of length 1 to T is: <br>
# > $ \sum_{t = 1}^{T} 6^t $ <br>
# ### (b)
# | Precept Sequence | Action |
# | --- | --- |
# | [A, Clean] | Right |
# | [A, Dirty] | Suck |
# | [B, Clean] | Right |
# | [B, Dirty] | Suck |
# | [C, Clean] | NoOp |
# | [C, Dirty] | Suck |
# ### (c)
# ```text
# function ReflexVacuumAgent([location, status]) returns an action
#     if status = Dirty then return Suck
#     else if location = A or B then return Right
#     else if location = C return NoOp
# ```
# > $ \sum_{t = 1}^{10} 6^t = 72,559,410 $
# The comparison between the above pseudocode and equation shows that percept sequence tables can explode to unreasonable sizes very quickly even when describing simple behavior that is easily accomplished in code.
# ### (d)
# When changing the performance measure to penalize movement the above agent from (c) is still rational. This is because the agent will only move across each square once and will then infinitely NoOp due to the condition stating that the floors stay clean once cleaned; the agent will still receive a maximum score.
# ### (e)
